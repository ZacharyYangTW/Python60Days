# %%
import numpy as np
import seaborn as sns

#設定圖形樣式 - whitegrid
# use sns.set
sns.set(style="whitegrid")

# 利用 NUMPY 去建立資料集
# np.random.RandomState 設定數學式
rs = np.random.RandomState(0)
x = rs.normal(2, 1, 75)
y = 2 + 1.5 * x + rs.normal(0, 2, 75)

# 畫圖
# sns.residplot
sns.residplot(x=x, y=y);

# %%
# bin: 指的是特徵值, 
# kde: on/off
# sns.distplot();

sns.displot(x, bins=20, kde=False, rug=True);

# %%
# bin: 指的是特徵值, 
# kde: on/off
# sns.distplot();

sns.displot(x, bins=20, kde=True, rug=True);

# %%
# bin: 指的是特徵值, 
# kde: on/off
# sns.distplot();

sns.displot(x, bins=1, kde=False, rug=True);

# %%
# bin: 指的是特徵值, 
# kde: on/off
# sns.distplot();

sns.displot(x, bins=100, kde=False, rug=True);
